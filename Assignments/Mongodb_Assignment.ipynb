# %%
# !pip install pymongo
# !pip install dnspython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 15.6 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient
from pymongo.server_api import ServerApi
import urllib

import ssl  # Import the ssl module

username = "sankarallof" ## put your userid
password = "Sankar2002" ### ur pass word

# Encode the username and password
encoded_username = urllib.parse.quote_plus(username)
encoded_password = urllib.parse.quote_plus(password)

ssl_context = ssl.create_default_context(ssl.Purpose.SERVER_AUTH)
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE

# Construct the URI with encoded credentials
uri = f"mongodb+srv://{encoded_username}:{encoded_password}@cluster0.nb81bns.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'), tz_aware=False, connect=True)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['sample_analytics']
trans = db['transactions']

# %%
list(trans.find().limit(1))
# Out:
# [{'_id': ObjectId('5ca4bbc1a2dd94ee58161cbc'),
#   'account_id': 795909,
#   'transaction_count': 78,
#   'bucket_start_date': datetime.datetime(1963, 7, 18, 0, 0),
#   'bucket_end_date': datetime.datetime(2016, 12, 25, 0, 0),
#   'transactions': [{'date': datetime.datetime(2009, 1, 6, 0, 0),
#     'amount': 5242,
#     'transaction_code': 'sell',
#     'symbol': 'adbe',
#     'price': '23.539134478555158835888505564071238040924072265625',
#     'total': '123392.1429365861426177275462'},
#    {'date': datetime.datetime(2002, 9, 10, 0, 0),
#     'amount': 3105,
#     'transaction_code': 'buy',
#     'symbol': 'adbe',
#     'price': '9.71044534866879160972530371509492397308349609375',
#     'total': '30150.93280761659794819706804'},
#    {'date': datetime.datetime(2013, 1, 25, 0, 0),
#     'amount': 5787,
#     'transaction_code': 'buy',
#     'symbol': 'ibm',
#     'price': '176.2255467574028671151609160006046295166015625',
#     'total': '1019817.239085090391995436221'},
# ...

# %%
list(trans.find({},{'transactions.amount':1}).limit(2))
# Out:
# [{'_id': ObjectId('5ca4bbc1a2dd94ee58161cbc'),
#   'transactions': [{'amount': 5242},
#    {'amount': 3105},
#    {'amount': 5787},
#    {'amount': 7443},
#    {'amount': 4429},
#    {'amount': 788},
#    {'amount': 3640},
#    {'amount': 185},
#    {'amount': 9581},
#    {'amount': 1342},
#    {'amount': 5916},
#    {'amount': 7158},
#    {'amount': 1270},
#    {'amount': 4889},
#    {'amount': 2249},
#    {'amount': 2423},
#    {'amount': 2968},
#    {'amount': 4584},
#    {'amount': 2287},
#    {'amount': 8658},
#    {'amount': 5819},
#    {'amount': 1690},
#    {'amount': 2591},
#    {'amount': 9733},
#    {'amount': 9831},
#    {'amount': 5027},
#    {'amount': 6108},
#    {'amount': 3002},
#    {'amount': 6349},
#    {'amount': 9683},
#    {'amount': 5069},
#    {'amount': 5783},
#    {'amount': 7005},
#    {'amount': 3476},
#    {'amount': 4968},
#    {'amount': 3286},
#    {'amount': 5486},
#    {'amount': 9141},
#    {'amount': 9561},
#    {'amount': 1914},
# ...

# %%
maximum = trans.aggregate([
    {"$group":{"_id":"$account_id","maximum_amount":{"$max":"$transactions.amount"}}}
])

# %%
maximum

# %%
list(maximum)
# Out:
# [{'_id': 54977,
#   'maximum_amount': [7923,
#    6932,
#    8026,
#    2236,
#    5088,
#    3401,
#    6436,
#    5742,
#    1156,
#    2690,
#    4275,
#    502,
#    8781,
#    1619,
#    4841]},
#  {'_id': 147334,
#   'maximum_amount': [7404,
#    9919,
#    949,
#    7266,
#    7088,
#    1343,
#    4514,
#    596,
#    7206,
#    4923,
#    8664,
#    7177,
#    6975,
#    7466,
#    1863,
#    2297,
#    6826,
#    2898,
#    3753,
#    515,
#    5974,
#    440,
#    2320,
#    4106,
#    204,
#    1386,
#    4963,
#    6009,
#    2607,
#    7463,
#    9698,
#    3928,
#    5076,
#    5772,
#    8517,
#    4053,
#    562,
#    3213,
#    2555,
#    3373,
#    2003,
#    5459,
#    6465,
#    354,
#    1271,
#    77,
#    3441,
#    407,
#    3643,
#    7638,
#    5895,
#    1129,
#    5066,
#    9090,
#    6791,
#    5784,
#    8124,
#    7743,
#    6318,
#    426,
#    8712,
#    9222,
#    7200,
#    7758,
#    5772,
#    6085,
#    8371,
#    4372,
#    66,
#    9454,
# ...

# %%
minimum = trans.aggregate([
    {"$group":{"_id":"$account_id","minimum_amount":{"$min":"$transactions.amount"}}}
])

# %%
minimum

# %%
list(minimum)
# Out:
# [{'_id': 588722,
#   'minimum_amount': [2476,
#    966,
#    7081,
#    8074,
#    2516,
#    3695,
#    5787,
#    6959,
#    1668,
#    1958,
#    6145,
#    8095,
#    2123,
#    614,
#    8520,
#    4558,
#    8893,
#    6539,
#    2908,
#    5734,
#    901,
#    1995,
#    1341,
#    1954,
#    316,
#    5274,
#    4641,
#    3389,
#    4651,
#    4369,
#    1939,
#    1419,
#    2952,
#    7150,
#    2088,
#    8594,
#    4589,
#    6968,
#    8451,
#    6799,
#    1682,
#    92,
#    9999,
#    7437,
#    5171,
#    3574,
#    5928,
#    2662,
#    7112,
#    990,
#    3320,
#    6317,
#    1597,
#    1978,
#    3765,
#    6435,
#    7753,
#    980,
#    7052,
#    7480,
#    8347,
#    6025,
#    3392,
#    8254,
#    7278,
#    5580,
#    3814,
#    9043,
#    9144]},
#  {'_id': 871666,
#   'minimum_amount': [1321, 931, 934, 7808, 5074, 1825, 4515, 9381, 1957]},
#  {'_id': 392268,
#   'minimum_amount': [1156,
#    146,
#    6295,
#    5861,
#    3565,
#    9145,
#    3355,
# ...

# %%
average = trans.aggregate([
    {"$group":{"_id":"$account_id","average_amount":{"$avg":"$transactions.amount"}}}
])

# %%
average

# %%
list(average)
# Out:
# [{'_id': 358036, 'average_amount': None},
#  {'_id': 899684, 'average_amount': None},
#  {'_id': 507622, 'average_amount': None},
#  {'_id': 387979, 'average_amount': None},
#  {'_id': 725209, 'average_amount': None},
#  {'_id': 377923, 'average_amount': None},
#  {'_id': 87965, 'average_amount': None},
#  {'_id': 182103, 'average_amount': None},
#  {'_id': 463155, 'average_amount': None},
#  {'_id': 840171, 'average_amount': None},
#  {'_id': 388334, 'average_amount': None},
#  {'_id': 828552, 'average_amount': None},
#  {'_id': 278669, 'average_amount': None},
#  {'_id': 931483, 'average_amount': None},
#  {'_id': 733789, 'average_amount': None},
#  {'_id': 506711, 'average_amount': None},
#  {'_id': 570536, 'average_amount': None},
#  {'_id': 300714, 'average_amount': None},
#  {'_id': 987355, 'average_amount': None},
#  {'_id': 624886, 'average_amount': None},
#  {'_id': 813161, 'average_amount': None},
#  {'_id': 955053, 'average_amount': None},
# ...
