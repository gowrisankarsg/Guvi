# %%
import pandas as pd

# %%
df = pd.read_excel("/content/Assignment-1_Data.xlsx")

# %%
df
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 522059  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522060  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522061  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522062  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522063  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                       Date  Price  CustomerID         Country
# 0      2010-12-01 08:26:00   2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00   3.39     17850.0  United Kingdom
# ...

# %%
pd.to_datetime(df['Date'],format="%Y-%m-%d %I:%M")
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 522059   2011-12-09 12:50:00
# 522060   2011-12-09 12:50:00
# 522061   2011-12-09 12:50:00
# 522062   2011-12-09 12:50:00
# 522063   2011-12-09 12:50:00
# Name: Date, Length: 522064, dtype: datetime64[ns]

# %%
df['date'] = df['Date'].dt.strftime("%d-%m-%Y")

# %%
df['date'] = pd.to_datetime(df['date'],format="%d-%m-%Y")

# %%
df['time'] = df['Date'].dt.strftime("%I:%M")

# %%
df['time']= pd.to_datetime(df['time'],format="%I:%M").dt.time

# %%
df['Price'].dtype
# Out:
# dtype('float64')

# %%
df['price'] = df['Quantity']*df['Price']

# %%
df["days"] = (pd.to_datetime("30-09-2023")-df['date']).dt.days
# Out:
# <ipython-input-12-5db80005d9cf>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["days"] = (pd.to_datetime("30-09-2023")-df['date']).dt.days

# %%
df['days'].dtype
# Out:
# dtype('int64')

# %%
df['month'] = df['date'].dt.month

# %%
df['year'] = df['date'].dt.year

# %%
df
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 522059  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522060  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522061  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522062  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522063  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                       Date  Price  CustomerID         Country       date  \
# 0      2010-12-01 08:26:00   2.55     17850.0  United Kingdom 2010-12-01
# ...

# %% [markdown]
# # Q1. Which item more buy

# %%
item_qty = df.groupby(['Itemname'])['Quantity'].sum().reset_index()
item_qty
# Out:
#                           Itemname  Quantity
# 0            *Boombox Ipod Classic         1
# 1          *USB Office Mirror Ball         2
# 2           10 COLOUR SPACEBOY PEN      6300
# 3       12 COLOURED PARTY BALLOONS      2095
# 4        12 DAISY PEGS IN WOOD BOX       301
# ...                            ...       ...
# 4180   wrongly marked carton 22804      -256
# 4181  wrongly marked. 23343 in box     -3100
# 4182  wrongly sold (22719) barcode       170
# 4183          wrongly sold as sets      -600
# 4184             wrongly sold sets      -975
#
# [4185 rows x 2 columns]

# %%
item_qty.iloc[item_qty['Quantity'].idxmax()]
# Out:
# Itemname    PAPER CRAFT , LITTLE BIRDIE
# Quantity                          80995
# Name: 2420, dtype: object

# %% [markdown]
# # Q2. Which customer recent buy

# %%
recent_day = df['days'].min()

# %%
df.query('days == @recent_day',engine="python")
# Out:
#         BillNo                             Itemname  Quantity  \
# 520439  581475  CHRISTMAS STAR WISH LIST CHALKBOARD        36
# 520440  581475             STORAGE TIN VINTAGE LEAF        12
# 520441  581475    TREE T-LIGHT HOLDER WILLIE WINKIE        12
# 520442  581475    SET OF 4 KNICK KNACK TINS POPPIES         6
# 520443  581475              BAG 500g SWIRLY MARBLES        24
# ...        ...                                  ...       ...
# 522059  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522060  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522061  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522062  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522063  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                       Date  Price  CustomerID         Country       date  \
# 520439 2011-12-09 08:39:00   0.39     13069.0  United Kingdom 2011-12-09
# ...

# %%
recent_buy = df.query('days == @recent_day',engine="python")[['CustomerID','days']]
recent_buy
# Out:
#         CustomerID  days
# 520439     13069.0  4313
# 520440     13069.0  4313
# 520441     13069.0  4313
# 520442     13069.0  4313
# 520443     13069.0  4313
# ...            ...   ...
# 522059     12680.0  4313
# 522060     12680.0  4313
# 522061     12680.0  4313
# 522062     12680.0  4313
# 522063     12680.0  4313
#
# [1625 rows x 2 columns]

# %%
recent_buy['CustomerID'].unique()
# Out:
# array([13069., 12433., 13426., 17364., 14441., 17490., 16446., 17389.,
#        17001., 15694., 17428., 16954.,    nan, 12423., 12518., 14051.,
#        16558., 15344., 12985., 15910., 17754., 14422., 14446., 18102.,
#        16626., 12662., 15311., 16705., 12526., 12713., 17581., 12748.,
#        13777., 15804., 13113., 12680.])

# %%
recent_buy['CustomerID'].nunique()
# Out:
# 35

# %% [markdown]
# # Q3. Which customer more price buy

# %%
more_price = df.groupby(['CustomerID'])['price'].sum().reset_index()
more_price
# Out:
#       CustomerID     price
# 0        12346.0  77183.60
# 1        12347.0   4310.00
# 2        12349.0   1757.55
# 3        12350.0    334.40
# 4        12352.0   2506.04
# ...          ...       ...
# 4292     18280.0    180.60
# 4293     18281.0     80.82
# 4294     18282.0    178.05
# 4295     18283.0   2094.88
# 4296     18287.0   1837.28
#
# [4297 rows x 2 columns]

# %%
more_price.iloc[more_price['price'].idxmax()]
# Out:
# CustomerID     14646.00
# price         280206.02
# Name: 1661, dtype: float64

# %% [markdown]
# # Q4. Lowest Price

# %%
# Which customer less price purchase

less_price = df.groupby(['CustomerID'])['price'].sum().reset_index()
less_price
# Out:
#       CustomerID     price
# 0        12346.0  77183.60
# 1        12347.0   4310.00
# 2        12349.0   1757.55
# 3        12350.0    334.40
# 4        12352.0   2506.04
# ...          ...       ...
# 4292     18280.0    180.60
# 4293     18281.0     80.82
# 4294     18282.0    178.05
# 4295     18283.0   2094.88
# 4296     18287.0   1837.28
#
# [4297 rows x 2 columns]

# %%
less_price.iloc[less_price['price'].idxmin()]
# Out:
# CustomerID    13256.0
# price             0.0
# Name: 662, dtype: float64

# %%
# Which item lowest price purchase

low_price_item = df.groupby(['Itemname'])['price'].sum().reset_index()
low_price_item
# Out:
#                           Itemname    price
# 0            *Boombox Ipod Classic    16.98
# 1          *USB Office Mirror Ball    16.94
# 2           10 COLOUR SPACEBOY PEN  5361.05
# 3       12 COLOURED PARTY BALLOONS  1373.16
# 4        12 DAISY PEGS IN WOOD BOX   521.67
# ...                            ...      ...
# 4180   wrongly marked carton 22804     0.00
# 4181  wrongly marked. 23343 in box     0.00
# 4182  wrongly sold (22719) barcode     0.00
# 4183          wrongly sold as sets     0.00
# 4184             wrongly sold sets     0.00
#
# [4185 rows x 2 columns]

# %%
low_price_item.iloc[low_price_item['price'].idxmin()]
# Out:
# Itemname    Adjust bad debt
# price             -11062.06
# Name: 268, dtype: object

# %%
find_lowprice = low_price_item.query(" price > 0 ")
find_lowprice
# Out:
#                               Itemname    price
# 0                *Boombox Ipod Classic    16.98
# 1              *USB Office Mirror Ball    16.94
# 2               10 COLOUR SPACEBOY PEN  5361.05
# 3           12 COLOURED PARTY BALLOONS  1373.16
# 4            12 DAISY PEGS IN WOOD BOX   521.67
# ...                                ...      ...
# 4062   ZINC T-LIGHT HOLDER STARS SMALL  4108.19
# 4063     ZINC TOP  2 DOOR WOODEN SHELF   270.08
# 4064  ZINC WILLIE WINKIE  CANDLE STICK  2631.95
# 4065       ZINC WIRE KITCHEN ORGANISER   219.17
# 4066  ZINC WIRE SWEETHEART LETTER TRAY   265.62
#
# [4005 rows x 2 columns]

# %%
find_lowprice.iloc[find_lowprice['price'].idxmin()]
# Out:
# Itemname    PAPER LANTERN 6 POINT SNOW STAR
# price                                 107.9
# Name: 2425, dtype: object

# %% [markdown]
# # Q5. How many items

# %%
df['Itemname'].nunique()
# Out:
# 4185

# %% [markdown]
# # Q6. How many customer

# %%
df['CustomerID'].nunique()
# Out:
# 4297

# %% [markdown]
# # Q7. Sorted price

# %%
df.sort_values("Price")[['Price']]
# Out:
#            Price
# 288774 -11062.06
# 288773 -11062.06
# 343819      0.00
# 40271       0.00
# 233693      0.00
# ...          ...
# 258372   4287.63
# 286674   4505.17
# 167329   8142.75
# 288772  11062.06
# 14696   13541.33
#
# [522064 rows x 1 columns]

# %% [markdown]
# # Q8. Price unique

# %%
df['Price'].nunique()
# Out:
# 1285

# %%
df['Price'].unique()
# Out:
# array([   2.55,    3.39,    2.75, ...,    4.76,  933.17, 1714.17])

# %% [markdown]
# # Q9. Which Country purchase highest and lowest price

# %%
df['Country'].nunique()
# Out:
# 30

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'Switzerland', 'Spain', 'Poland', 'Portugal', 'Italy',
#        'Belgium', 'Lithuania', 'Japan', 'Iceland', 'Sweden', 'Austria',
#        'Bahrain', 'Israel', 'Greece', 'Hong Kong', 'Singapore', 'Lebanon',
#        'United Arab Emirates', 'Saudi Arabia', 'Unspecified', 'Brazil',
#        'USA', 'Malta', 'RSA'], dtype=object)

# %%
country = df.groupby(['Country'])['price'].sum().reset_index()
country
# Out:
#                  Country        price
# 0              Australia   138521.310
# 1                Austria    10198.680
# 2                Bahrain      754.140
# 3                Belgium    41196.340
# 4                 Brazil     1143.600
# 5                 France   209715.110
# 6                Germany   228867.140
# 7                 Greece     4760.520
# 8              Hong Kong    15691.800
# 9                Iceland     4310.000
# 10                Israel     8135.260
# 11                 Italy    17483.240
# 12                 Japan    37416.370
# 13               Lebanon     1693.880
# 14             Lithuania     1661.060
# 15                 Malta     2725.590
# 16           Netherlands   285446.340
# 17                Norway    36165.440
# 18                Poland     7334.650
# 19              Portugal    33747.100
# 20                   RSA     1002.310
# 21          Saudi Arabia      145.920
# 22             Singapore    21279.290
# 23                 Spain    61577.110
# ...

# %%
High_price = country.iloc[country['price'].idxmax()]
High_price
# Out:
# Country    United Kingdom
# price         9003097.964
# Name: 28, dtype: object

# %%
low_price = country.iloc[country['price'].idxmin()]
low_price
# Out:
# Country    Saudi Arabia
# price            145.92
# Name: 21, dtype: object

# %% [markdown]
# # Q10. Which date high and low price purchase

# %%
df['day'] = df['date'].dt.day

# %%
df
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 522059  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522060  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522061  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522062  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522063  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                       Date  Price  CustomerID         Country       date  \
# 0      2010-12-01 08:26:00   2.55     17850.0  United Kingdom 2010-12-01
# ...

# %%
df['day'].nunique()
# Out:
# 31

# %%
df['day'].unique()
# Out:
# array([ 1,  2,  3,  5,  6,  7,  8,  9, 10, 12, 13, 14, 15, 16, 17, 19, 20,
#        21, 22, 23,  4, 11, 18, 24, 25, 26, 27, 28, 30, 31, 29])

# %%
day_price = df.groupby(['day'])['price'].sum().reset_index()
day_price
# Out:
#     day       price
# 0     1  300693.150
# 1     2  302382.540
# 2     3  324358.750
# 3     4  371673.160
# 4     5  398421.520
# 5     6  384272.340
# 6     7  518852.180
# 7     8  388480.670
# 8     9  511855.740
# 9    10  382929.170
# 10   11  398413.290
# 11   12  234400.070
# 12   13  286054.060
# 13   14  406042.660
# 14   15  333388.311
# 15   16  298443.900
# 16   17  391629.850
# 17   18  429405.680
# 18   19  252562.320
# 19   20  396308.240
# 20   21  384424.920
# 21   22  284917.540
# 22   23  280920.190
# 23   24  314448.210
# 24   25  277690.781
# 25   26  200713.132
# 26   27  248236.240
# 27   28  320962.960
# 28   29  232380.920
# 29   30  243078.690
# 30   31  181429.670

# %%
day_price_high = day_price.iloc[day_price['price'].idxmax()]
day_price_high
# Out:
# day           7.00
# price    518852.18
# Name: 6, dtype: float64

# %%
day_price_low = day_price.iloc[day_price['price'].idxmin()]
day_price_low
# Out:
# day          31.00
# price    181429.67
# Name: 30, dtype: float64

# %% [markdown]
# # Q11. Which month high and low price purchase

# %%
month_price = df.groupby(['month'])['price'].sum().reset_index()
month_price
# Out:
#     month        price
# 0       1   667348.270
# 1       2   504110.560
# 2       3   680937.780
# 3       4   528064.801
# 4       5   750270.080
# 5       6   728512.720
# 6       7   670612.991
# 7       8   712122.520
# 8       9  1008307.912
# 9      10  1119034.830
# 10     11  1471012.430
# 11     12  1439435.960

# %%
month_price_high = month_price.iloc[month_price['price'].idxmax()]
month_price_high
# Out:
# month         11.00
# price    1471012.43
# Name: 10, dtype: float64

# %%
month_price_low = month_price.iloc[month_price['price'].idxmin()]
month_price_low
# Out:
# month         2.00
# price    504110.56
# Name: 1, dtype: float64

# %% [markdown]
# # Q12. Which year high and low price purchase

# %%
df['year'].nunique()
# Out:
# 2

# %%
df['year'].unique()
# Out:
# array([2010, 2011])

# %%
year_price = df.groupby(['year'])['price'].sum().reset_index()
year_price
# Out:
#    year        price
# 0  2010   809584.230
# 1  2011  9470186.624

# %%
year_price_high = year_price.iloc[year_price['price'].idxmax()]
year_price_high
# Out:
# year        2011.000
# price    9470186.624
# Name: 1, dtype: float64

# %%
year_price_low = year_price.iloc[year_price['price'].idxmin()]
year_price_low
# Out:
# year       2010.00
# price    809584.23
# Name: 0, dtype: float64
